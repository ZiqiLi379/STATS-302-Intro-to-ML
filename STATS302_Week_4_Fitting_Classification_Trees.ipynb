# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiqiLi379/STATS-302-Intro-to-ML/blob/main/STATS302_Week_4_Fitting_Classification_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Week 4 - Fitting Classification Trees
# ###STATS 302 Principle of Machine Learning
# ###Duke Kunshan University

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

# for viewing graphs
from IPython.display import HTML
from google.colab import files
import io

# %%
# carseats = pd.read_csv('E:\programming\dataset\Into_to_statstical_learning\Carseats.csv')

uploaded = files.upload()
carseats = pd.read_csv(io.BytesIO(uploaded['Carseats.csv']))
data = carseats.copy()
print(carseats.shape)
carseats.head()
# Out:
#      <input type="file" id="files-642329b5-6ee5-4ff4-92dd-c5df37bc4659" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-642329b5-6ee5-4ff4-92dd-c5df37bc4659">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Carseats.csv to Carseats.csv
# (400, 11)
#    Sales  CompPrice  Income  Advertising  ...  Age  Education Urban   US
# 0   9.50        138      73           11  ...   42         17   Yes  Yes
# 1  11.22        111      48           16  ...   65         10   Yes  Yes
# 2  10.06        113      35           10  ...   59         12   Yes  Yes
# 3   7.40        117     100            4  ...   55         14   Yes  Yes
# 4   4.15        141      64            3  ...   38         13   Yes   No
#
# [5 rows x 11 columns]

# %% [markdown]
# Before going furthur, according to me its a good advice to get familier with the data. The current data we have is of an organization who sells car seats, each row represents a region. Therefore for each region, the columns are -
# - Sales: unit sales in thousands
# - CompPrice: price charged by competitor at each location
# - Income: community income level in 1000s of dollars
# - Advertising: local ad budget at each location in 1000s of dollars
# - Population: regional pop in thousands
# - Price: price for car seats at each site
# - ShelveLoc: Bad, Good or Medium indicates quality of shelving location
# - Age: age level of the population
# - Education: ed level at location
# - Urban: Yes/No
# - US: Yes/No

# %% [markdown]
# Looking at the above data we can get some idea what job we have in our hands, so the company wants to set up a busniess in some new region, we have the information of that region and want to predict what the sales would be..To make the model we will use this data as training data
# source - http://rstudio-pubs-static.s3.amazonaws.com/244643_520e0851a0f74d9fb588c8aaad481e21.html#:~:text=The%20Carseats%20data%20set%20tracks,different%20store)%20and%2011%20variables%3A&text=Price%3A%20price%20for%20car%20seats,indicates%20quality%20of%20shelving%20location

# %% [markdown]
# ### Encoding the categorical variables

# %%
print(data['ShelveLoc'].unique())
print(data['Urban'].unique())
print(data['US'].unique())
# Out:
# ['Bad' 'Good' 'Medium']
# ['Yes' 'No']
# ['Yes' 'No']

# %%
# as the labels are ordinal, we would only be using label encoder, and since the values are small in number, we will map them
yes_no_dict = {'Yes':1,'No':0}
data['Urban'] = data['Urban'].map(yes_no_dict)
data['US'] = data['US'].map(yes_no_dict)
data['ShelveLoc'] = data['ShelveLoc'].map({'Bad':0,'Good':1,'Medium':3})
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  ...  Age  Education  Urban  US
# 0   9.50        138      73           11  ...   42         17      1   1
# 1  11.22        111      48           16  ...   65         10      1   1
# 2  10.06        113      35           10  ...   59         12      1   1
# 3   7.40        117     100            4  ...   55         14      1   1
# 4   4.15        141      64            3  ...   38         13      1   0
#
# [5 rows x 11 columns]

# %%
data.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc        int64
# Age              int64
# Education        int64
# Urban            int64
# US               int64
# dtype: object

# %%
# adding a binary target variable
data['Sales_binary'] = np.where(data['Sales']<=9,0,1)
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  ...  Education  Urban  US  Sales_binary
# 0   9.50        138      73           11  ...         17      1   1             1
# 1  11.22        111      48           16  ...         10      1   1             1
# 2  10.06        113      35           10  ...         12      1   1             1
# 3   7.40        117     100            4  ...         14      1   1             0
# 4   4.15        141      64            3  ...         13      1   0             0
#
# [5 rows x 12 columns]

# %%
# splitting X and y
X = data.drop(['Sales','Sales_binary'],axis = 1)
y = data['Sales_binary']

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
clf = DecisionTreeClassifier(max_depth=6)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# Plotting tree - https://mljar.com/blog/visualize-decision-tree/

# %%
#plotting tree
import graphviz

# DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=X.columns,
                                class_names=['0','1'],
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data)
display(HTML(graph._repr_svg_()))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: Tree Pages: 1 -->
# <svg width="2710pt" height="790pt"
#  viewBox="0.00 0.00 2709.50 790.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 786)">
# <title>Tree</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-786 2705.5,-786 2705.5,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="#efb387" stroke="#000000" points="685.5,-782 561.5,-782 561.5,-699 685.5,-699 685.5,-782"/>
# <text text-anchor="middle" x="623.5" y="-766.8" font-family="Times,serif" font-size="14.00" fill="#000000">Price &lt;= 89.5</text>
# <text text-anchor="middle" x="623.5" y="-751.8" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.405</text>
# <text text-anchor="middle" x="623.5" y="-736.8" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 400</text>
# <text text-anchor="middle" x="623.5" y="-721.8" font-family="Times,serif" font-size="14.00" fill="#000000">value = [287, 113]</text>
# <text text-anchor="middle" x="623.5" y="-706.8" font-family="Times,serif" font-size="14.00" fill="#000000">class = 0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <polygon fill="#90c8f0" stroke="#000000" points="474,-663 353,-663 353,-580 474,-580 474,-663"/>
# <text text-anchor="middle" x="413.5" y="-647.8" font-family="Times,serif" font-size="14.00" fill="#000000">ShelveLoc &lt;= 0.5</text>
# <text text-anchor="middle" x="413.5" y="-632.8" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.425</text>
# <text text-anchor="middle" x="413.5" y="-617.8" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 49</text>
# <text text-anchor="middle" x="413.5" y="-602.8" font-family="Times,serif" font-size="14.00" fill="#000000">value = [15, 34]</text>
# <text text-anchor="middle" x="413.5" y="-587.8" font-family="Times,serif" font-size="14.00" fill="#000000">class = 1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="#000000" d="M561.3454,-705.2791C536.6783,-691.301 508.2032,-675.1652 482.8681,-660.8086"/>
# <polygon fill="#000000" stroke="#000000" points="484.475,-657.6963 474.0492,-655.8112 481.0238,-663.7865 484.475,-657.6963"/>
# <text text-anchor="middle" x="480.7138" y="-676.2065" font-family="Times,serif" font-size="14.00" fill="#000000">True</text>
# </g>
# <!-- 16 -->
# <g id="node17" class="node">
# <title>16</title>
# <polygon fill="#eda673" stroke="#000000" points="972,-663 845,-663 845,-580 972,-580 972,-663"/>
# <text text-anchor="middle" x="908.5" y="-647.8" font-family="Times,serif" font-size="14.00" fill="#000000">Advertising &lt;= 6.5</text>
# <text text-anchor="middle" x="908.5" y="-632.8" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.349</text>
# <text text-anchor="middle" x="908.5" y="-617.8" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 351</text>
# <text text-anchor="middle" x="908.5" y="-602.8" font-family="Times,serif" font-size="14.00" fill="#000000">value = [272, 79]</text>
# <text text-anchor="middle" x="908.5" y="-587.8" font-family="Times,serif" font-size="14.00" fill="#000000">class = 0</text>
# </g>
# <!-- 0&#45;&gt;16 -->
# <g id="edge16" class="edge">
# <title>0&#45;&gt;16</title>
# <path fill="none" stroke="#000000" d="M685.6923,-714.532C729.8223,-696.1058 789.2089,-671.3093 835.5736,-651.95"/>
# <polygon fill="#000000" stroke="#000000" points="837.0823,-655.1129 844.9616,-648.0301 834.3851,-648.6534 837.0823,-655.1129"/>
# <text text-anchor="middle" x="835.4601" y="-667.4541" font-family="Times,serif" font-size="14.00" fill="#000000">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <polygon fill="#efb388" stroke="#000000" points="229.5,-544 91.5,-544 91.5,-461 229.5,-461 229.5,-544"/>
# <text text-anchor="middle" x="160.5" y="-528.8" font-family="Times,serif" font-size="14.00" fill="#000000">CompPrice &lt;= 118.5</text>
# <text text-anchor="middle" x="160.5" y="-513.8" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.408</text>
# <text text-anchor="middle" x="160.5" y="-498.8" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 14</text>
# <text text-anchor="middle" x="160.5" y="-483.8" font-family="Times,serif" font-size="14.00" fill="#000000">value = [10, 4]</text>
# <text text-anchor="middle" x="160.5" y="-468.8" font-family="Times,serif" font-size="14.00" fill="#000000">class = 0</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="#000000" d="M352.9002,-592.9965C318.6696,-576.896 275.507,-556.5942 238.7418,-539.3015"/>
# <polygon fill="#000000" stroke="#000000" points="240.0807,-536.0634 229.5419,-534.9743 237.1012,-542.3977 240.0807,-536.0634"/>
# </g>
# <!-- 7 -->
# <g id="node8" class="node">
# <title>7</title>
# <polygon fill="#5aade9" stroke="#000000" points="482,-544 345,-544 345,-461 482,-461 482,-544"/>
# <text text-anchor="middle" x="413.5" y="-528.8" font-family="Times,serif" font-size="14.00" fill="#000000">Population &lt;= 494.5</text>
# <text text-anchor="middle" x="413.5" y="-513.8" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.245</text>
# <text text-anchor="middle" x="413.5" y="-498.8" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 35</text>
# <text text-anchor="middle" x="413.5" y="-483.8" font-family="Times,serif" font-size="14.00" fill="#000000">value = [5, 30]</text>
# <text text-anchor="middle" x="413.5" y="-468.8" font-family="Times,serif" font-size="14.00" fill="#000000">class = 1</text>
# </g>
# <!-- 1&#45;&gt;7 -->
# <g id="edge7" class="edge">
# <title>1&#45;&gt;7</title>
# <path fill="none" stroke="#000000" d="M413.5,-579.8796C413.5,-571.6838 413.5,-562.9891 413.5,-554.5013"/>
# <polygon fill="#000000" stroke="#000000" points="417.0001,-554.298 413.5,-544.2981 410.0001,-554.2981 417.0001,-554.298"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <polygon fill="#e58139" stroke="#000000" points="95,-417.5 0,-417.5 0,-349.5 95,-349.5 95,-417.5"/>
# <text text-anchor="middle" x="47.5" y="-402.3" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.0</text>
# <text text-anchor="middle" x="47.5" y="-387.3" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 8</text>
# <text text-anchor="middle" x="47.5" y="-372.3" font-family="Times,serif" font-size="14.00" fill="#000000">value = [8, 0]</text>
# <text text-anchor="middle" x="47.5" y="-357.3" font-family="Times,serif" font-size="14.00" fill="#000000">class = 0</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge3" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="#000000" d="M120.9781,-460.8796C110.0143,-449.3337 98.1103,-436.7976 87.1399,-425.2446"/>
# <polygon fill="#000000" stroke="#000000" points="89.5087,-422.6564 80.0848,-417.8149 84.4327,-427.4766 89.5087,-422.6564"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <polygon fill="#9ccef2" stroke="#000000" points="208,-425 113,-425 113,-342 208,-342 208,-425"/>
# <text text-anchor="middle" x="160.5" y="-409.8" font-family="Times,serif" font-size="14.00" fill="#000000">Age &lt;= 78.5</text>
# <text text-anchor="middle" x="160.5" y="-394.8" font-family="Times,serif" font-size="14.00" fill="#000000">gini = 0.444</text>
# <text text-anchor="middle" x="160.5" y="-379.8" font-family="Times,serif" font-size="14.00" fill="#000000">samples = 6</text>
# <text text-anchor="middle" x="160.5" y="-364.8" font-family="Times,serif" font-size="14.00" fill="#000000">value = [2, 4]</text>
# <text text-anchor="middle" x="160.5" y="-349.8" font-family="Times,serif" font-size="14.00" fill="#000000">class = 1</text>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g id="edge4" class="edge">
# <title>2&#45;

# %%
# to make the above graph more readable, we can use -
# DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=X.columns,
                                class_names=['0','1'],
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png")
graph

# %% [markdown]
# What we can get from the above tree is that the most important crietrion is the price feature. if the price is less than or equal to 89.5, we look at shelving condition, else we look at advertising cost..

# %% [markdown]
# ## Finding the test error

# %%
X_train,X_test,y_train,y_test = train_test_split(data.drop(['Sales','Sales_binary'],axis = 1),data['Sales_binary'],test_size = 0.5,random_state = 1)

# %%
clf = DecisionTreeClassifier(max_depth = 5)
clf.fit(X_train,y_train)
print('Training accuracy ',clf.score(X_train,y_train))
print('Test Accuracy ',clf.score(X_test,y_test))
# Out:
# Training accuracy  0.94
# Test Accuracy  0.715

# %%
cm = confusion_matrix(y_test,clf.predict(X_test))
cm
# Out:
# array([[125,  21],
#        [ 36,  18]])

# %% [markdown]
# # cross validating for optimal size

# %%
scores_dict = {}
for max_depth in np.arange(2,15):
    clf = DecisionTreeClassifier(max_depth = max_depth)
    scores_dict[max_depth] = np.mean(cross_val_score(clf,X,y,cv = 10))

# %%
plt.figure(figsize = (10,6))
plt.plot(list(scores_dict.keys()),list(scores_dict.values()),marker ='o')
plt.plot(max(scores_dict, key=scores_dict.get),max(list(scores_dict.values())),marker = 'o',markersize = 8,color = 'r',label = 'Best Tree')
plt.xlabel('Depth of Tree')
plt.ylabel('10 CV accuracy')
plt.legend()
